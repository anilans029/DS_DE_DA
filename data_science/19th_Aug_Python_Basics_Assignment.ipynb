# %% [markdown]
# ## *TOPIC: Python Basics Variable*

# %% [markdown]
# #### 1. Declare two variables, `x` and `y`, and assign them integer values. Swap the values of these variables without using any temporary variable.

# %% [markdown]
# ###### solution

# %%
## x and y declared with values 10 and 20 respectively
x = 10
y = 20

print(f'before swapping: x ={x}, y ={y} ')

## swaping 
x, y = y,x
print(f'after swapping: x ={x}, y ={y} ')
# Out:
# before swapping: x =10, y =20
# after swapping: x =20, y =10

# %% [markdown]
# #### 2. Create a program that calculates the area of a rectangle. Take the length and width as inputs from the user and store them in variables. Calculate and display the area.

# %% [markdown]
# ###### solution

# %%
"""
area of a rectangle = length * breadth
"""
length = int(input("enter the value of length in number"))
breadth = int(input("enter the value of breadth in number"))

print(f"entered length ={length} breadth ={breadth} ")

#calculating the area
area = length * breadth
print(f"area of a rectangle = {area}")
# Out:
# enter the value of length in number 10
# enter the value of breadth in number 20
# entered length =10 breadth =20
# area of a rectangle = 200

# %% [markdown]
# #### 3. Write a Python program that converts temperatures from Celsius to Fahrenheit. Take the temperature in Celsius as input, store it in a variable, convert it to Fahrenheit, and display the result.

# %% [markdown]
# ###### solution

# %%
"""
(1°C × 9/5) + 32 = 33.8°F
"""
celcius = int(input("enter the temperature in Celcius"))
print(f"entered celcius in degrees = {celcius}")

fahrenheit = celcius * 9/5 +32
print(f"{celcius} °C = {fahrenheit} °F")
# Out:
# enter the temperature in Celcius 37
# entered celcius in degrees = 37
# 37 °C = 98.6 °F

# %% [markdown]
# ###

# %% [markdown]
# ## *TOPIC: String Based Questions*

# %% [markdown]
# #### 1. Write a Python program that takes a string as input and prints the length of the string.

# %% [markdown]
# ###### solution

# %%
inp_string = input("enter anything that you are thinking:  ")
len_of_inp_string = len(inp_string)
print(len_of_inp_string)
# Out:
# enter anything that you are thinking:   hello anil how are you
# 22

# %% [markdown]
# #### 2. Create a program that takes a sentence from the user and counts the number of vowels (a, e, i, o, u) in the string.

# %% [markdown]
# ###### solution

# %%
inp_string = input("enter anything that you are thinking:  ")
vowels = ['a', 'e', 'i', 'o', 'u']
vowels_found = [letter for letter in inp_string if letter in vowels]
print(f"{len(vowels_found)} vowels found in the entered sentence. i.e, {vowels_found}")
# Out:
# enter anything that you are thinking:   hello anil
# 4 vowels found in the entered sentence. i.e, ['e', 'o', 'a', 'i']

# %% [markdown]
# #### 3. Given a string, reverse the order of characters using string slicing and print the reversed string.

# %% [markdown]
# ###### solution

# %%
given_strig = "anil is my name"
reversed_string = given_strig[::-1]
print(f"given string = {given_strig}")
print(f"reversed string = {reversed_string}")
# Out:
# given string = anil is my name
# reversed string = eman ym si lina

# %% [markdown]
# #### 4. Write a program that takes a string as input and checks if it is a palindrome (reads the same forwards and backwards).

# %% [markdown]
# ###### solution

# %%
entered_string = input("enter anything that you are thinking:  ")
n = len(entered_string)
i,j = 0,n-1
while i<j:
    if entered_string[i] != entered_string[j]:
        print(f"entered string '{entered_string}' is not a palindrome")
        break
    else:
        i+= 1
        j-= 1
else:
    print(f"entered string '{entered_string}' is a palindrome")
# Out:
# enter anything that you are thinking:   tenet
# entered string 'tenet' is a palindrome

# %% [markdown]
# #### 5. Create a program that takes a string as input and removes all the spaces from it. Print the modified string without spaces.

# %% [markdown]
# ###### solution

# %%
entered_string = input("enter anything that you are thinking:  ")
string_wo_spaces = entered_string.replace(" ", '')
print(f"entered string w/o spaces : {string_wo_spaces}")
# Out:
# enter anything that you are thinking:   hey, anil! what's up
# entered string w/o spaces : hey,anil!what'sup
